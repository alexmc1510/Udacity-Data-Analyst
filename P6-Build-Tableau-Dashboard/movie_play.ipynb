# %%
# Import the libraries needed
import pandas as pd
import numpy as np
import re
import calendar

# %%
# Load the data into a pandas dataframe
movies_play = pd.read_csv("data/movies_cleaned.csv")
movies_play
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# 5      281957  tt1663202    9.110700  135000000   532950503
# 6       87101  tt1340138    8.654359  155000000   440603537
# 7      286217  tt3659388    7.667400  108000000   595380321
# 8      211672  tt2293640    7.404165   74000000  1156730962
# 9      150540  tt2096673    6.326804  175000000   853708609
# 10     206647  tt2379713    6.200282  245000000   880674609
# 11      76757  tt1617661    6.189369  176000003   183987723
# 12     264660  tt0470752    6.118847   15000000    36869414
# 13     257344  tt2120120    5.984995   88000000   243637091
# 14      99861  tt2395427    5.944927  280000000  1405035767
# ...

# %%
movies_play.dtypes
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# homepage                 object
# director                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# based_on_novel           object
# release_month            object
# release_day               int64
# release_dayofweek        object
# profit                    int64
# profit (%)              float64
# profit_adj              float64
# dtype: object

# %%
class1 = (movies_play["based_on_novel"][(movies_play["vote_average"] > 5.947) & 
        (movies_play["profit_adj"] > 1000000000)].value_counts())/(movies_play["based_on_novel"].value_counts())
class1
# Out:
# False    0.003538
# True     0.007692
# Name: based_on_novel, dtype: float64

# %%
class2 = movies_play["based_on_novel"][(movies_play["vote_average"] > 5.947) & 
        (movies_play["profit_adj"] > 500000000)].value_counts()/(movies_play["based_on_novel"].value_counts())
class2
# Out:
# False    0.019106
# True     0.030769
# Name: based_on_novel, dtype: float64

# %%
class3 = movies_play["based_on_novel"][(movies_play["vote_average"] > 5.947) & 
        (movies_play["profit_adj"] > 250000000)].value_counts()/(movies_play["based_on_novel"].value_counts())
class3
# Out:
# False    0.050241
# True     0.073077
# Name: based_on_novel, dtype: float64

# %%
class4 = movies_play["based_on_novel"][(movies_play["vote_average"] > 5.947) & 
        (movies_play["profit_adj"] > 0)].value_counts()/(movies_play["based_on_novel"].value_counts())
class4
# Out:
# False    0.293660
# True     0.461538
# Name: based_on_novel, dtype: float64

# %%
y = movies_play["based_on_novel"].value_counts()
y
# Out:
# False    7066
# True      260
# Name: based_on_novel, dtype: int64

# %%
x = movies_play["based_on_novel"][(movies_play["vote_average"] > 5.947) & 
        (movies_play["profit_adj"] > 1000000000)].value_counts()
x
# Out:
# False    25
# True      2
# Name: based_on_novel, dtype: int64

# %%
2/260
# Out:
# 0.007692307692307693
