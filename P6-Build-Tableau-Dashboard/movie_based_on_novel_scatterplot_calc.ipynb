# %%
# Import the libraries needed
import pandas as pd
import numpy as np
import re
import calendar

# %%
# Load the data into a pandas dataframe. 
# The steps for generating this dataset is described in the Build-Tableau-Dashboard.ipynb notebook
movies_cleaned = pd.read_csv("data/movies_cleaned.csv")
movies_cleaned.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
movies_cleaned.dtypes
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# homepage                 object
# director                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# based_on_novel           object
# release_month            object
# release_day               int64
# release_dayofweek        object
# profit                    int64
# profit (%)              float64
# profit_adj              float64
# dtype: object

# %% [markdown]
# Find proportion of movies that have `vote_average` > average `vote_average` and `profit_adj` > average profit_adj for each category - `based_on_novel` True and False. I call this quadrant magic quadrant.

# %%
magic_quadrant = (movies_cleaned["based_on_novel"][(movies_cleaned["vote_average"] > 5.947) & 
        (movies_cleaned["profit_adj"] > 41937684)].value_counts())/(movies_cleaned["based_on_novel"].value_counts())
magic_quadrant
# Out:
# False    0.173082
# True     0.296154
# Name: based_on_novel, dtype: float64
